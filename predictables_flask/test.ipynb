# %%
from predictables_flask.manage import deploy
from predictables_flask.models.User import User
# Out:
# db: <SQLAlchemy>
# db.Model: <class 'sqlalchemy.orm.decl_api.Model'>
# type(db): <class 'flask_sqlalchemy.extension.SQLAlchemy'>
# type(db.Model): <class 'flask_sqlalchemy.model.DefaultMeta'>

# %%
app, db = deploy()
with app.app_context():
    db.create_all()
    if not User.get_by_username("admin"):
        User.create("admin", "admin", "admin")
# Out:
# 2023-12-21 14:11:11,487 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-12-21 14:11:11,488 INFO sqlalchemy.engine.Engine COMMIT
# Creating directory '/home/aweaver/work/predictables-flask/predictables_flask/migrations' ...  done
# Creating directory '/home/aweaver/work/predictables-flask/predictables_flask/migrations/versions' ...  done
# Generating /home/aweaver/work/predictables-flask/predictables_flask/migrations/env.py ...  done
# Generating /home/aweaver/work/predictables-flask/predictables_flask/migrations/README ...  done
# Generating /home/aweaver/work/predictables-flask/predictables_flask/migrations/script.py.mako ...  done
# Generating /home/aweaver/work/predictables-flask/predictables_flask/migrations/alembic.ini ...  done
# Please edit configuration/connection/logging settings in '/home/aweaver/work/predictables-flask/predictables_flask/migrations/alembic.ini' before proceeding.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# ...

# %%
# !pytest ./api/v1/auth/tests/test_login.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-7.4.3, pluggy-1.3.0
# rootdir: /home/aweaver/work/predictables-flask
# collected 5 items
#
# api/v1/auth/tests/test_login.py FFF..                                    [100%]
#
# =================================== FAILURES ===================================
# _________________________ test_login[test_input0-200] __________________________
#
# test_input = {'password': 'valid_pass', 'username': 'valid_user'}
# expected_status = 200, app = <Flask 'predictables_flask.app'>
#
#     @pytest.mark.parametrize("test_input, expected_status", test_data)
#     def test_login(test_input, expected_status, app):
#         with app.test_request_context(json=test_input):
# >           response = login(request)
#
# api/v1/auth/tests/test_login.py:39:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# request = <LocalProxy unbound>
#
# ...
